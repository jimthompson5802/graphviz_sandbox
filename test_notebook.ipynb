# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
# !which dot
# Out:
# /opt/conda/envs/myenv/bin/dot

# %%
import graphviz  # doctest: +NO_EXE
dot = graphviz.Digraph(comment='The Round Table')
dot  #doctest: +ELLIPSIS
# Out:
# Warning: Could not load "/opt/conda/envs/myenv/lib/graphviz/libgvplugin_pango.so.6" - It was found, so perhaps one of its dependents was not.  Try ldd.

# %%
dot.node('A', 'King Arthur')  # doctest: +NO_EXE
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

# %%
dot.node('A', 'King Arthur')  # doctest: +NO_EXE
dot.node('B', 'Sir Bedevere the Wise')
dot.node('L', 'Sir Lancelot the Brave')

dot.edges(['AB', 'AL'])
dot.edge('B', 'L', constraint='false')

# %%
# doctest_mark_exe()  # skip this line

dot.render('doctest-output/round-table.gv', view=True)  # doctest: +SKIP
'doctest-output/round-table.gv.pdf'
# Out:
# Warning: Could not load "/opt/conda/envs/myenv/lib/graphviz/libgvplugin_pango.so.6" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Warning: Could not load "/opt/conda/envs/myenv/lib/graphviz/libgvplugin_pango.so.6" - It was found, so perhaps one of its dependents was not.  Try ldd.
# Format: "pdf" not recognized. Use one of: bmp canon cmap cmapx cmapx_np dot dot_json eps fig gd gd2 gif gv ico imap imap_np ismap jpe jpeg jpg json json0 mp pdf pic plain plain-ext png pov ps ps2 svg svgz tif tiff tk vdx vml vmlz vrml wbmp webp xdot xdot1.2 xdot1.4 xdot_json
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File /opt/conda/envs/myenv/lib/python3.11/site-packages/graphviz/backend/execute.py:88, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      87 try:
# ---> 88     proc.check_returncode()
#      89 except subprocess.CalledProcessError as e:
#
# File /opt/conda/envs/myenv/lib/python3.11/subprocess.py:502, in CompletedProcess.check_returncode(self)
#     501 if self.returncode:
# --> 502     raise CalledProcessError(self.returncode, self.args, self.stdout,
#     503                              self.stderr)
#
# CalledProcessError: Command '[PosixPath('dot'), '-Kdot', '-Tpdf', '-O', 'round-table.gv']' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# CalledProcessError                        Traceback (most recent call last)
# Cell In[7], line 3
#       1 # doctest_mark_exe()  # skip this line
# ----> 3 dot.render('doctest-output/round-table.gv', view=True)  # doctest: +SKIP
#       4 'doctest-output/round-table.gv.pdf'
#
# File /opt/conda/envs/myenv/lib/python3.11/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File /opt/conda/envs/myenv/lib/python3.11/site-packages/graphviz/rendering.py:122, in Render.render(self, filename, directory, view, cleanup, format, renderer, formatter, neato_no_op, quiet, quiet_view, outfile, engine, raise_if_result_exists, overwrite_source)
#     118 filepath = self.save(filename, directory=directory, skip_existing=None)
#     120 args.append(filepath)
# --> 122 rendered = self._render(*args, **kwargs)
#     124 if cleanup:
#     125     log.debug('delete %r', filepath)
#
# File /opt/conda/envs/myenv/lib/python3.11/site-packages/graphviz/_tools.py:171, in deprecate_positional_args.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     162     wanted = ', '.join(f'{name}={value!r}'
#     163                        for name, value in deprecated.items())
#     164     warnings.warn(f'The signature of {func.__name__} will be reduced'
#     165                   f' to {supported_number} positional args'
#     166                   f' {list(supported)}: pass {wanted}'
#     167                   ' as keyword arg(s)',
#     168                   stacklevel=stacklevel,
#     169                   category=category)
# --> 171 return func(*args, **kwargs)
#
# File /opt/conda/envs/myenv/lib/python3.11/site-packages/graphviz/backend/rendering.py:326, in render(engine, format, filepath, renderer, formatter, neato_no_op, quiet, outfile, raise_if_result_exists, overwrite_filepath)
#     322 cmd += args
#     324 assert filepath is not None, 'work around pytype false alarm'
# --> 326 execute.run_check(cmd,
#     327                   cwd=filepath.parent if filepath.parent.parts else None,
#     328                   quiet=quiet,
#     329                   capture_output=True)
#     331 return os.fspath(outfile)
#
# File /opt/conda/envs/myenv/lib/python3.11/site-packages/graphviz/backend/execute.py:90, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      88     proc.check_returncode()
#      89 except subprocess.CalledProcessError as e:
# ---> 90     raise CalledProcessError(*e.args)
#      92 return proc
#
# CalledProcessError: Command '[PosixPath('dot'), '-Kdot', '-Tpdf', '-O', 'round-table.gv']' returned non-zero exit status 1. [stderr: b'Warning: Could not load "/opt/conda/envs/myenv/lib/graphviz/libgvplugin_pango.so.6" - It was found, so perhaps one of its dependents was not.  Try ldd.\nWarning: Could not load "/opt/conda/envs/myenv/lib/graphviz/libgvplugin_pango.so.6" - It was found, so perhaps one of its dependents was not.  Try ldd.\nFormat: "pdf" not recognized. Use one of: bmp canon cmap cmapx cmapx_np dot dot_json eps fig gd gd2 gif gv ico imap imap_np ismap jpe jpeg jpg json json0 mp pdf pic plain plain-ext png pov ps ps2 svg svgz tif tiff tk vdx vml vmlz vrml wbmp webp xdot xdot1.2 xdot1.4 xdot_json\n']

# %%
# !ldd /opt/conda/envs/myenv/lib/graphviz/libgvplugin_pango.so.6
# Out:
# 	libgvc.so.6 => /opt/conda/envs/myenv/lib/graphviz/../libgvc.so.6 (0x00002aaaab2bd000)
# 	libcgraph.so.6 => /opt/conda/envs/myenv/lib/graphviz/../libcgraph.so.6 (0x00002aaaab35e000)
# 	libpangocairo-1.0.so.0 => /opt/conda/envs/myenv/lib/graphviz/../libpangocairo-1.0.so.0 (0x00002aaaab378000)
# 	libcairo.so.2 => /opt/conda/envs/myenv/lib/graphviz/../libcairo.so.2 (0x00002aaaab389000)
# 	libpangoft2-1.0.so.0 => /opt/conda/envs/myenv/lib/graphviz/../libpangoft2-1.0.so.0 (0x00002aaaab495000)
# 	libpango-1.0.so.0 => /opt/conda/envs/myenv/lib/graphviz/../libpango-1.0.so.0 (0x00002aaaab4b1000)
# 	libgobject-2.0.so.0 => /opt/conda/envs/myenv/lib/graphviz/../libgobject-2.0.so.0 (0x00002aaaab519000)
# 	libglib-2.0.so.0 => /opt/conda/envs/myenv/lib/graphviz/../libglib-2.0.so.0 (0x00002aaaab57c000)
# 	libm.so.6 => /lib/x86_64-linux-gnu/libm.so.6 (0x00002aaaab6ca000)
# 	libc.so.6 => /lib/x86_64-linux-gnu/libc.so.6 (0x00002aaaab7b3000)
# 	libltdl.so.7 => /opt/conda/envs/myenv/lib/graphviz/.././libltdl.so.7 (0x00002aaaab9c7000)
# 	libcdt.so.5 => /opt/conda/envs/myenv/lib/graphviz/.././libcdt.so.5 (0x00002aaaab9d2000)
# 	libpathplan.so.4 => /opt/conda/envs/myenv/lib/graphviz/.././libpathplan.so.4 (0x00002aaaab9db000)
# 	libexpat.so.1 => /opt/conda/envs/myenv/lib/graphviz/.././libexpat.so.1 (0x00002aaaab9e4000)
# 	libz.so.1 => /opt/conda/envs/myenv/lib/graphviz/.././libz.so.1 (0x00002aaaaba14000)
# 	libharfbuzz.so.0 => /opt/conda/envs/myenv/lib/graphviz/.././libharfbuzz.so.0 (0x00002aaaaba34000)
# 	libfontconfig.so.1 => /opt/conda/envs/myenv/lib/graphviz/.././libfontconfig.so.1 (0x00002aaaabb32000)
# 	libpixman-1.so.0 => /opt/conda/envs/myenv/lib/graphviz/.././libpixman-1.so.0 (0x00002aaaabb7f000)
# 	libfreetype.so.6 => /opt/conda/envs/myenv/lib/graphviz/.././libfreetype.so.6 (0x00002aaaabc3b000)
# 	libpng16.so.16 => /opt/conda/envs/myenv/lib/graphviz/.././libpng16.so.16 (0x00002aaaabcf5000)
# 	libxcb-shm.so.0 => /opt/conda/envs/myenv/lib/graphviz/.././libxcb-shm.so.0 (0x00002aaaabd34000)
# 	libxcb.so.1 => /opt/conda/envs/myenv/lib/graphviz/.././libxcb.so.1 (0x00002aaaabd3a000)
# 	libxcb-render.so.0 => /opt/conda/envs/myenv/lib/graphviz/.././libxcb-render.so.0 (0x00002aaaabd66000)
# 	libXrender.so.1 => not found
# 	libX11.so.6 => /lib/x86_64-linux-gnu/libX11.so.6 (0x00002aaaabd76000)
# 	libXext.so.6 => /lib/x86_64-linux-gnu/libXext.so.6 (0x00002aaaabeb5000)
# 	librt.so.1 => /lib/x86_64-linux-gnu/librt.so.1 (0x00002aaaabec9000)
# 	libgio-2.0.so.0 => /opt/conda/envs/myenv/lib/graphviz/.././libgio-2.0.so.0 (0x00002aaaabece000)
# 	libfribidi.so.0 => /opt/conda/envs/myenv/lib/graphviz/.././libfribidi.so.0 (0x00002aaaac0ab000)
# 	libffi.so.8 => /opt/conda/envs/myenv/lib/graphviz/.././libffi.so.8 (0x00002aaaac0cb000)
# 	libiconv.so.2 => /opt/conda/envs/myenv/lib/graphviz/.././libiconv.so.2 (0x00002aaaac0de000)
# 	libpcre2-8.so.0 => /opt/conda/envs/myenv/lib/graphviz/.././libpcre2-8.so.0 (0x00002aaaac1c5000)
# 	libpthread.so.0 => /lib/x86_64-linux-gnu/libpthread.so.0 (0x00002aaaac267000)
# 	/lib64/ld-linux-x86-64.so.2 (0x0000555555556000)
# 	libdl.so.2 => /lib/x86_64-linux-gnu/libdl.so.2 (0x00002aaaac26c000)
# 	libgraphite2.so.3 => /opt/conda/envs/myenv/lib/graphviz/../././libgraphite2.so.3 (0x00002aaaac271000)
# 	libxml2.so.2 => /opt/conda/envs/myenv/lib/graphviz/../././libxml2.so.2 (0x00002aaaac29f000)
# 	libXau.so.6 => /lib/x86_64-linux-gnu/libXau.so.6 (0x00002aaaac3ff000)
# 	libgmodule-2.0.so.0 => /opt/conda/envs/myenv/lib/graphviz/../././libgmodule-2.0.so.0 (0x00002aaaac405000)
# 	libresolv.so.2 => /lib/x86_64-linux-gnu/libresolv.so.2 (0x00002aaaac40c000)
# 	liblzma.so.5 => /opt/conda/envs/myenv/lib/graphviz/.././././liblzma.so.5 (0x00002aaaac421000)
# 	libicuuc.so.73 => /opt/conda/envs/myenv/lib/graphviz/.././././libicuuc.so.73 (0x00002aaaac451000)
# 	libicudata.so.73 => /opt/conda/envs/myenv/lib/graphviz/../././././libicudata.so.73 (0x00002aaaac65c000)
# 	libstdc++.so.6 => /opt/conda/envs/myenv/lib/graphviz/../././././libstdc++.so.6 (0x00002aaaae4e4000)
# 	libgcc_s.so.1 => /opt/conda/envs/myenv/lib/graphviz/../././././libgcc_s.so.1 (0x00002aaaae6f8000)
